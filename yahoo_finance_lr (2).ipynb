# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('stock_data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## One hot encoding

# %%
pd.get_dummies(dataset, columns = ['Company'])
print(dataset)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-11-20   44.592499   45.367500   43.877499   44.244999   42.466824
# 1     2018-11-20   71.875000   76.737503   71.000000   74.773003   74.773003
# 2     2018-11-20  127.029999  134.160004  126.849998  132.429993  132.429993
# 3     2018-11-20   22.783333   23.320000   22.236668   23.166000   23.166000
# 4     2018-11-21   44.932499   45.067501   44.137501   44.195000   42.418831
# ...          ...         ...         ...         ...         ...         ...
# 5023  2023-11-16  189.570007  190.960007  188.649994  189.710007  189.710007
# 5024  2023-11-17  330.260010  335.500000  329.350006  335.040009  335.040009
# 5025  2023-11-17  190.250000  190.380005  188.570007  189.690002  189.690002
# 5026  2023-11-17  142.660004  145.229996  142.539993  145.179993  145.179993
# 5027  2023-11-17  232.000000  237.389999  226.539993  234.300003  234.300003
#
#          Volume Company
# 0     271300800    AAPL
# 1     217576000    AMZN
# 2      41939500    META
# 3     120070500    TSLA
# 4     124496800    AAPL
# ...         ...     ...
# 5023   54412900    AAPL
# 5024   14494400    META
# 5025   50922700    AAPL
# 5026   49636700    AMZN
# 5027  142532800    TSLA
#
# [5028 rows x 8 columns]

# %%
print(X)
# Out:
# [['2018-11-20' 44.592499 45.3675 ... 44.244999 42.466824 271300800]
#  ['2018-11-20' 71.875 76.737503 ... 74.773003 74.773003 217576000]
#  ['2018-11-20' 127.029999 134.160004 ... 132.429993 132.429993 41939500]
#  ...
#  ['2023-11-17' 190.25 190.380005 ... 189.690002 189.690002 50922700]
#  ['2023-11-17' 142.660004 145.229996 ... 145.179993 145.179993 49636700]
#  ['2023-11-17' 232.0 237.389999 ... 234.300003 234.300003 142532800]]

# %%
print(y)
# Out:
# ['AAPL' 'AMZN' 'META' ... 'AAPL' 'AMZN' 'TSLA']

# %% [markdown]
# ## Data preprocessing

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5028 entries, 0 to 5027
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5028 non-null   object
#  1   Open       5028 non-null   float64
#  2   High       5028 non-null   float64
#  3   Low        5028 non-null   float64
#  4   Close      5028 non-null   float64
#  5   Adj Close  5028 non-null   float64
#  6   Volume     5028 non-null   int64
#  7   Company    5028 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 314.4+ KB

# %%
dataset.head(20)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2018-11-20   44.592499   45.367500   43.877499   44.244999   42.466824
# 1   2018-11-20   71.875000   76.737503   71.000000   74.773003   74.773003
# 2   2018-11-20  127.029999  134.160004  126.849998  132.429993  132.429993
# 3   2018-11-20   22.783333   23.320000   22.236668   23.166000   23.166000
# 4   2018-11-21   44.932499   45.067501   44.137501   44.195000   42.418831
# 5   2018-11-21   77.149498   77.500000   75.750000   75.836502   75.836502
# 6   2018-11-21   23.466667   23.540001   22.493334   22.546000   22.546000
# 7   2018-11-21  134.399994  137.190002  134.130005  134.820007  134.820007
# 8   2018-11-23   43.735001   44.150002   43.025002   43.072498   41.341454
# 9   2018-11-23  133.649994  134.500000  131.259995  131.729996  131.729996
# 10  2018-11-23   75.849998   76.809998   75.090500   75.102997   75.102997
# 11  2018-11-23   22.290001   22.500000   21.703333   21.722000   21.722000
# 12  2018-11-26  133.000000  137.000000  132.779999  136.380005  136.380005
# 13  2018-11-26   76.949997   79.240501   76.210999   79.066498   79.066498
# 14  2018-11-26   43.560001   43.737499   42.564999   43.654999   41.900536
# 15  2018-11-26   21.666668   23.081333   21.666668   23.066668   23.066668
# 16  2018-11-27  135.750000  136.610001  133.710007  135.000000  135.000000
# 17  2018-11-27   78.799500   79.882500   77.900497   79.070999   79.070999
# 18  2018-11-27   22.670000   23.130667   22.366667   22.927999   22.927999
# 19  2018-11-27   42.877499   43.692501   42.720001   43.560001   41.809361
#
#        Volume Company
# 0   271300800    AAPL
# 1   217576000    AMZN
# 2    41939500    META
# 3   120070500    TSLA
# 4   124496800    AAPL
# 5   114336000    AMZN
# 6    70302000    TSLA
# 7    25469700    META
# 8    94496000    AAPL
# 9    11886100    META
# 10   54152000    AMZN
# 11   63039000    TSLA
# 12   24263600    META
# 13  125154000    AMZN
# 14  179994000    AAPL
# 15  119881500    TSLA
# 16   20750300    META
# 17  115664000    AMZN
# 18   95374500    TSLA
# 19  165549600    AAPL

# %%
dataset.shape
# Out:
# (5028, 8)

# %%
dataset.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Company      0
# dtype: int64

# %%
dataset['Log_Return'] = np.log(dataset['Close'] / dataset['Close'].shift(1))

# %%
dataset.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-11-20   44.592499   45.367500   43.877499   44.244999   42.466824
# 1  2018-11-20   71.875000   76.737503   71.000000   74.773003   74.773003
# 2  2018-11-20  127.029999  134.160004  126.849998  132.429993  132.429993
# 3  2018-11-20   22.783333   23.320000   22.236668   23.166000   23.166000
# 4  2018-11-21   44.932499   45.067501   44.137501   44.195000   42.418831
# 5  2018-11-21   77.149498   77.500000   75.750000   75.836502   75.836502
# 6  2018-11-21   23.466667   23.540001   22.493334   22.546000   22.546000
# 7  2018-11-21  134.399994  137.190002  134.130005  134.820007  134.820007
# 8  2018-11-23   43.735001   44.150002   43.025002   43.072498   41.341454
# 9  2018-11-23  133.649994  134.500000  131.259995  131.729996  131.729996
#
#       Volume Company  Log_Return
# 0  271300800    AAPL         NaN
# 1  217576000    AMZN    0.524715
# 2   41939500    META    0.571597
# 3  120070500    TSLA   -1.743368
# 4  124496800    AAPL    0.645926
# 5  114336000    AMZN    0.539968
# 6   70302000    TSLA   -1.213022
# 7   25469700    META    1.788383
# 8   94496000    AAPL   -1.141056
# 9   11886100    META    1.117870

# %%
dataset.dropna(inplace=True)

# %%
dataset.head(10)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 1   2018-11-20   71.875000   76.737503   71.000000   74.773003   74.773003
# 2   2018-11-20  127.029999  134.160004  126.849998  132.429993  132.429993
# 3   2018-11-20   22.783333   23.320000   22.236668   23.166000   23.166000
# 4   2018-11-21   44.932499   45.067501   44.137501   44.195000   42.418831
# 5   2018-11-21   77.149498   77.500000   75.750000   75.836502   75.836502
# 6   2018-11-21   23.466667   23.540001   22.493334   22.546000   22.546000
# 7   2018-11-21  134.399994  137.190002  134.130005  134.820007  134.820007
# 8   2018-11-23   43.735001   44.150002   43.025002   43.072498   41.341454
# 9   2018-11-23  133.649994  134.500000  131.259995  131.729996  131.729996
# 10  2018-11-23   75.849998   76.809998   75.090500   75.102997   75.102997
#
#        Volume Company  Log_Return
# 1   217576000    AMZN    0.524715
# 2    41939500    META    0.571597
# 3   120070500    TSLA   -1.743368
# 4   124496800    AAPL    0.645926
# 5   114336000    AMZN    0.539968
# 6    70302000    TSLA   -1.213022
# 7    25469700    META    1.788383
# 8    94496000    AAPL   -1.141056
# 9    11886100    META    1.117870
# 10   54152000    AMZN   -0.561894

# %%
X = dataset[['Open', 'High', 'Low', 'Adj Close', 'Volume']]
y = dataset['Log_Return']

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
print(X_train)
print(y_train)
# Out:
#             Open        High         Low   Adj Close     Volume
# 701    88.511002   89.433502   87.439003   88.256500  121164000
# 3478  313.006653  315.200012  285.899994  291.093323   92519100
# 3645  143.289993  146.550003  143.279999  145.093964   66253700
# 2210  264.000000  268.850006  263.269989  267.079987   17320800
# 4610  183.740005  187.050003  183.669998  186.502106   51245300
# ...          ...         ...         ...         ...        ...
# 2896  337.000000  338.839996  328.980011  329.220001   28307500
# 2764  147.440002  148.500000  146.779999  146.302414   60549600
# 906   188.320007  189.699997  186.899994  189.550003   10516900
# 3981  142.059998  142.800003  138.750000  137.879318   97918500
# 236    80.050003   81.699997   80.028000   81.378998   73634000
#
# [4021 rows x 5 columns]
# 701     1.757549
# 3478    0.334761
# 3645   -0.162597
# 2210    0.457649
# 4610   -0.347148
#           ...
# 2896    0.840899
# 2764   -0.873960
# 906     2.392983
# 3981    0.445986
# 236     1.377457
# Name: Log_Return, Length: 4021, dtype: float64

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
print(len(X_train), len(y_train))
# Out:
# 4021 4021

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# ## Calculating Accuracy Score
#
# ---

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 0.6391145710142173

# %% [markdown]
# ## Visualising the Training set results

# %%
plt.scatter(X_train["Volume"], y_train, color = 'red')
plt.plot(X_train["Volume"], regressor.predict(X_train), color = 'blue')
plt.title('Log return x Volume')
plt.xlabel('Volume')
plt.ylabel('Log return')
plt.show()

# %%
plt.scatter(X_test["Open"], y_test, color = 'red')
plt.plot(X_train["Open"], regressor.predict(X_train), color = 'blue')
plt.title('Log return x Open')
plt.xlabel('Open')
plt.ylabel('Log return')
plt.show()

# %% [markdown]
# ## Visualising the Test set results

# %%
results = pd.DataFrame({'Volume': X_test.index, 'Actual_Log_Return': y_test, 'Predicted_Log_Return': y_pred})
results = results.set_index('Volume')

plt.figure(figsize=(12, 6))
plt.plot(results.index, results['Actual_Log_Return'], label='Actual Log Return', marker='o')
plt.plot(results.index, results['Predicted_Log_Return'], label='Predicted Log Return', marker='o')
plt.title('Actual vs. Predicted Logarithmic Return')
plt.xlabel('Volume')
plt.ylabel('Logarithmic Return')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 5))
errors = results['Actual_Log_Return'] - results['Predicted_Log_Return']
plt.hist(errors, bins=30, edgecolor='black')
plt.title('Error Distribution')
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(results['Actual_Log_Return'], results['Predicted_Log_Return'])
plt.plot([results['Actual_Log_Return'].min(), results['Actual_Log_Return'].max()],
         [results['Actual_Log_Return'].min(), results['Actual_Log_Return'].max()],
         linestyle='--', color='red', label='Perfect Fit')
plt.title('Actual vs. Predicted Logarithmic Return - Scatter Plot')
plt.xlabel('Actual Logarithmic Return')
plt.ylabel('Predicted Logarithmic Return')
plt.legend()
plt.show()

# %%
import seaborn as sns
correlation_matrix = dataset.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation plot")
plt.show()
# Out:
# <ipython-input-26-130178868c39>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = dataset.corr()
